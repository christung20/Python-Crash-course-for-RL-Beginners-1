# %% [markdown]
# # 🧠 Python Crash Course for Reinforcement Learning Beginners (2 Hours)
# Welcome! This notebook will teach you the basics of Python in under 2 hours — just enough to begin learning Reinforcement Learning (RL). Let's dive in! 🚀

# %%
# 👋 Introduction

# %% [markdown]
# ## 📦 Variables and Data Types

# %%
# Numbers
# Strings
# Booleans

# %% [markdown]
# ## 🔁 Conditional Logic and Loops

# %%
# If-else
# For loop
# While loop

# %% [markdown]
# ## 🧰 Functions and Inputs

# %% [markdown]
# ## 📚 Lists and Dictionaries

# %% [markdown]
# ## 🔄 Simulating an Environment (RL-style)

# %% [markdown]
# ## 🤖 Mini Agent

# %% [markdown]
# ## 🧪 Exercise: Build Your Own Environment

# %%
# TODO: Write a loop where the agent gets +1 reward for every step until it reaches the goal
# Optional challenge: Add penalties for certain actions
# Template:
# position = 0
# goal = 10
# reward = 0
# while position != goal:
#     position += 1
#     reward += 1
# print("Total reward:", reward)

# %% [markdown]
# ## ✅ What’s Next?

# %% [markdown]
# You now know:
# - Variables, loops, and conditions
# - Functions and logic
# - Simulating environments and agents
#
# 🎉 You're ready to explore Reinforcement Learning libraries like OpenAI Gym or NVIDIA’s beginner courses!
#
# Happy coding! 🚀
